# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('diabetes.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.sample()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 106            1       96            122              0        0  22.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 106                     0.207   27        0

# %%
df.sample(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 320            4      129             60             12      231  27.5
# 181            0      119             64             18       92  34.9
# 233            4      122             68              0        0  35.0
# 295            6      151             62             31      120  35.5
# 56             7      187             68             39      304  37.7
#
#      DiabetesPedigreeFunction  Age  Outcome
# 320                     0.527   31        0
# 181                     0.725   23        0
# 233                     0.394   29        0
# 295                     0.692   28        0
# 56                      0.254   41        1

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
#to display different types
list(df.columns)
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
tuple(df.columns)
# Out:
# ('Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome')

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# # EDA(exporatory data analysis--visualizing individial columns)

# %% [markdown]
# # Scatterplot:

# %%
import seaborn as sns
sns.scatterplot(x='Pregnancies', y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Outcome'>

# %% [markdown]
# We can see the number of weeks of pregnancies is equally distributed in the range 0 to 13

# %%
sns.scatterplot(x='Glucose', y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Outcome'>

# %% [markdown]
# we can see that gluscose is equally distributed in the range 55 to 200

# %%
sns.scatterplot(x='BloodPressure', y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel='BloodPressure', ylabel='Outcome'>

# %% [markdown]
# we can see that BloodPressure is equally distributed in the range 45 to 100

# %%
sns.scatterplot(x='SkinThickness', y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Outcome'>

# %% [markdown]
# we can see that SkinThickness is equally distributed in the range 5 to 55

# %%
sns.scatterplot(x='Insulin', y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Outcome'>

# %% [markdown]
# We can see the Insulin is equally distributed in the range 0 to 375

# %%
sns.scatterplot(x='BMI', y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Outcome'>

# %% [markdown]
# We can see that BMI is equally distributed in the range 25 to 50

# %%
sns.scatterplot(x='DiabetesPedigreeFunction', y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel='DiabetesPedigreeFunction', ylabel='Outcome'>

# %% [markdown]
# We can see that DiabetesPedigreeFunction is equally distributed in the range0 to 0 to 1.25

# %%
sns.scatterplot(x='Age', y='Outcome', data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Outcome'>

# %% [markdown]
# We can see that Age is equally distributed in the range 20 to 62

# %%
import matplotlib.pyplot as plt

# %%
sns.pairplot(df)

# %%
# by doing this we can open this image from homepage
sns.pairplot(df)
plt.savefig('pairplot.png')
plt.show()

# %% [markdown]
# # Correlation:

# %%
#dependacy of one column on another
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
# we want only outcome
df.corr()['Outcome']
# Out:
# Pregnancies                 0.221898
# Glucose                     0.466581
# BloodPressure               0.065068
# SkinThickness               0.074752
# Insulin                     0.130548
# BMI                         0.292695
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %%
#we want values in asscending values
df.corr()['Outcome'].sort_values()
# Out:
# BloodPressure               0.065068
# SkinThickness               0.074752
# Insulin                     0.130548
# DiabetesPedigreeFunction    0.173844
# Pregnancies                 0.221898
# Age                         0.238356
# BMI                         0.292695
# Glucose                     0.466581
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %% [markdown]
# correlation using heatmap

# %%
#fmt values of decimal number to be displayed

import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True, linewidth=0.5, linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # outcome of correlation

# %% [raw]
# All the columns of datasets is positively correlated with the target column
#
# Maximum correlation is with the  Glucose
# Minimum with the skin thikness

# %% [markdown]
# # Descriptive Statistics
# # Describing Datasets:

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
#visualizing the canvas
#[1:] is used to remove the first line and .transpose() is used to convert rows into columns and col into rows
#to round up the values into 2 place of decimal
#xticks is the name of the xaxis

plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title('Variables summary')
plt.savefig('heatmap.png')
plt.show()

# %% [raw]
# Outcome of describe datasets:
#
# 1: 768 rows
# 2: 9 columns
#
# pregnencies:
#     mean=3.845052
#     std=3.369578
#     max_values=17.000000
#     min_values=0
#
# Glucose:
#      mean=3.845052
#     std=3.369578
#     max_values=17.000000
#     min_values
#
#     Like wise enter the values for all columns
#
# Age: comes under categorical data
#
# outcome: this come under binary categirical data so descirbe shows no valid outcome.

# %%
#basic information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# From the above code we can have the columns datatype and memory used by dataframe
# For 8 gb ram dataset should not consume more that 6 gb

# %% [markdown]
# # Outliers Checking:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=df.columns.values
ncol=30
nrows=14

plt.figure(figsize=(ncol,3*ncol))
for i in range (0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data = df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# from the above outcome we can see that columns [pregnancy, glucose, skinthikness, bmi has less outliers]
# columns[ insulin, diabeticprdigreefunction and age ]has more outliers while the outcome columns has no outliers

# %% [markdown]
# # TO check which data set is outlier or  not we use Zscore

# %% [markdown]
# # Skewness:

# %%
#range os skewness is variable (+/- 0.5, 1/-1, 4,-4----)
#normal distribution  have skewness= 0
df.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %% [raw]
# outcomes of skewness: skewness threshold is taken as +/-0.65. columns which are having skewness:
#         Pregnancies
#         Bloodpressure
#         insulin
#         Diabeticpedigree function
#         Age

# %% [markdown]
# # Normal Distribution Curve:

# %%
sns.distplot(df["Pregnancies"])
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalized. The building blocks is out of the normalised curve

# %%
sns.distplot(df['Glucose'])
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Density'>

# %% [markdown]
# The data is not normalized. the building blocks is out of the normalized curve

# %%
sns.distplot(df['BloodPressure'])
# Out:
# <AxesSubplot:xlabel='BloodPressure', ylabel='Density'>

# %% [markdown]
# The data is not normalized. the building blocks is out of the normalized curve

# %%
sns.distplot(df['SkinThickness'])
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Density'>

# %% [raw]
# The data is not normalized. the building blocks is out of the normalized curve
# This plot is almost bimodel. Bimodel= Two modes(most occuring frequency)
# When where two modes are present we take only first mode with index 0

# %%
sns.distplot(df['Insulin'])
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Density'>

# %% [markdown]
# The data is not normalized. the building blocks is out of the normalized curve

# %%
sns.distplot(df['BMI'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# The data is not normalized. the building blocks is out of the normalized curve

# %%
sns.distplot(df['DiabetesPedigreeFunction'])
# Out:
# <AxesSubplot:xlabel='DiabetesPedigreeFunction', ylabel='Density'>

# %% [markdown]
# The data is not normalized. the building blocks is out of the normalized curve

# %%
sns.distplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [raw]
# The data is not normalized. the building blocks is out of the normalized curve
# The normal distribution curve of outcome is irrelevent

# %% [markdown]
# # The Normal Distribution shows that the data  is Skewed.

# %% [markdown]
# # Data Cleaning:

# %%
df.corr()['Outcome']
# Out:
# Pregnancies                 0.221898
# Glucose                     0.466581
# BloodPressure               0.065068
# SkinThickness               0.074752
# Insulin                     0.130548
# BMI                         0.292695
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %%
delete= pd.DataFrame([["0.065068","BloodPressure","No","Alot"],["0.074752","SkinThickness","No","Alot"]],columns=["Correlation with Target", "Column Name", "Normalised", "Outliers"])
delete
# Out:
#   Correlation with Target    Column Name Normalised Outliers
# 0                0.065068  BloodPressure         No     Alot
# 1                0.074752  SkinThickness         No     Alot

# %% [markdown]
# Here we are setting threshold of correlationas +/-0.1. It is not standard the datasets demands
#     We are droping the values which is between -/+0.1

# %%
#axis =o is row and axos =1 is column
df=df.drop(['BloodPressure','SkinThickness'], axis=1)

# %% [raw]
# df

# %% [markdown]
# # Removings outliers

# %% [markdown]
# We are using Zscore methods to identify and drop the outlier

# %% [raw]
# IQR proximity rule: one more method where we donot drop the outliers, but reassign the values of outlier

# %% [markdown]
# Z-Score Technique:

# %%
#here positive abd negative values are present
zscore(df)
# Out:
#      Pregnancies   Glucose   Insulin       BMI  DiabetesPedigreeFunction  \
# 0       0.639947  0.848324 -0.692891  0.204013                  0.468492
# 1      -0.844885 -1.123396 -0.692891 -0.684422                 -0.365061
# 2       1.233880  1.943724 -0.692891 -1.103255                  0.604397
# 3      -0.844885 -0.998208  0.123302 -0.494043                 -0.920763
# 4      -1.141852  0.504055  0.765836  1.409746                  5.484909
# ..           ...       ...       ...       ...                       ...
# 763     1.827813 -0.622642  0.870031  0.115169                 -0.908682
# 764    -0.547919  0.034598 -0.692891  0.610154                 -0.398282
# 765     0.342981  0.003301  0.279594 -0.735190                 -0.685193
# 766    -0.844885  0.159787 -0.692891 -0.240205                 -0.371101
# 767    -0.844885 -0.873019 -0.692891 -0.202129                 -0.473785
#
#           Age   Outcome
# 0    1.425995  1.365896
# 1   -0.190672 -0.732120
# 2   -0.105584  1.365896
# 3   -1.041549 -0.732120
# 4   -0.020496  1.365896
# ..        ...       ...
# 763  2.532136 -0.732120
# 764 -0.531023 -0.732120
# 765 -0.275760 -0.732120
# 766  1.170732  1.365896
# 767 -0.871374 -0.732120
#
# [768 rows x 7 columns]

# %%
#converting negative to positive
np.abs(zscore(df))
# Out:
#      Pregnancies   Glucose   Insulin       BMI  DiabetesPedigreeFunction  \
# 0       0.639947  0.848324  0.692891  0.204013                  0.468492
# 1       0.844885  1.123396  0.692891  0.684422                  0.365061
# 2       1.233880  1.943724  0.692891  1.103255                  0.604397
# 3       0.844885  0.998208  0.123302  0.494043                  0.920763
# 4       1.141852  0.504055  0.765836  1.409746                  5.484909
# ..           ...       ...       ...       ...                       ...
# 763     1.827813  0.622642  0.870031  0.115169                  0.908682
# 764     0.547919  0.034598  0.692891  0.610154                  0.398282
# 765     0.342981  0.003301  0.279594  0.735190                  0.685193
# 766     0.844885  0.159787  0.692891  0.240205                  0.371101
# 767     0.844885  0.873019  0.692891  0.202129                  0.473785
#
#           Age   Outcome
# 0    1.425995  1.365896
# 1    0.190672  0.732120
# 2    0.105584  1.365896
# 3    1.041549  0.732120
# 4    0.020496  1.365896
# ..        ...       ...
# 763  2.532136  0.732120
# 764  0.531023  0.732120
# 765  0.275760  0.732120
# 766  1.170732  1.365896
# 767  0.871374  0.732120
#
# [768 rows x 7 columns]

# %%
np.abs(zscore(df))<0
# Out:
#      Pregnancies  Glucose  Insulin    BMI  DiabetesPedigreeFunction    Age  \
# 0          False    False    False  False                     False  False
# 1          False    False    False  False                     False  False
# 2          False    False    False  False                     False  False
# 3          False    False    False  False                     False  False
# 4          False    False    False  False                     False  False
# ..           ...      ...      ...    ...                       ...    ...
# 763        False    False    False  False                     False  False
# 764        False    False    False  False                     False  False
# 765        False    False    False  False                     False  False
# 766        False    False    False  False                     False  False
# 767        False    False    False  False                     False  False
#
#      Outcome
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ..       ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
#
# [768 rows x 7 columns]

# %%
(np.abs(zscore(df))<0).sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
from scipy.stats import zscore

# %%
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (768, 7)

# %%
type(z)
# Out:
# pandas.core.frame.DataFrame

# %%
#if not applied np.abs
#threshold=(-3,3)



#if applied np.abs
threshold=3
#index number
print(np.where(z>3))
# Out:
# (array([  4,   8,   9,  13,  45,  49,  58,  60,  75,  81,  88, 111, 123,
#        145, 153, 159, 177, 182, 186, 220, 228, 228, 247, 286, 298, 330,
#        342, 349, 370, 370, 371, 371, 395, 409, 415, 426, 445, 445, 453,
#        455, 459, 486, 494, 502, 522, 584, 593, 621, 645, 655, 666, 673,
#        684, 684, 695, 706, 753], dtype=int64), array([4, 2, 3, 2, 4, 3, 4, 3, 1, 3, 0, 2, 5, 3, 2, 0, 3, 1, 2, 2, 2, 4,
#        2, 2, 0, 4, 1, 1, 2, 4, 3, 4, 4, 2, 2, 3, 3, 4, 5, 0, 5, 2, 3, 1,
#        3, 2, 4, 4, 2, 2, 5, 3, 3, 5, 2, 3, 2], dtype=int64))

# %%
    #to check the outliers present in the above array

    df.iloc[371]
# Out:
# Pregnancies                   0.000
# Glucose                     118.000
# Insulin                      89.000
# BMI                           0.000
# DiabetesPedigreeFunction      1.731
# Age                          21.000
# Outcome                       0.000
# Name: 371, dtype: float64

# %% [markdown]
# Hence we can makeout outliers are present

# %%
#To check the total number of outliers
len(np.where(z>3)[0])
# Out:
# 57

# %%
df.drop([ 4,   8,   9,  13,  45,  49,  58,  60,  75,  81,  88, 111, 123,
       145, 153, 159, 177, 182, 186, 220, 228, 228, 247, 286, 298, 330,
       342, 349, 370, 370, 371, 371, 395, 409, 415, 426, 445, 445, 453,
       455, 459, 486, 494, 502, 522, 584, 593, 621, 645, 655, 666, 673,
       684, 684, 695, 706, 753], axis=0)
# Out:
#      Pregnancies  Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age  \
# 0              6      148        0  33.6                     0.627   50
# 1              1       85        0  26.6                     0.351   31
# 2              8      183        0  23.3                     0.672   32
# 3              1       89       94  28.1                     0.167   21
# 5              5      116        0  25.6                     0.201   30
# ..           ...      ...      ...   ...                       ...  ...
# 763           10      101      180  32.9                     0.171   63
# 764            2      122        0  36.8                     0.340   27
# 765            5      121      112  26.2                     0.245   30
# 766            1      126        0  30.1                     0.349   47
# 767            1       93        0  30.4                     0.315   23
#
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 5          0
# ..       ...
# 763        0
# 764        0
# 765        0
# 766        1
# 767        0
#
# [716 rows x 7 columns]

# %% [markdown]
# df_new=df[(z<3).all(axis=1)]
# print("Old DataFrame", df.shape)
# print("New DataFrame", df_new.shape)
# print("total_dropped_rows", df.shape[0]-df_new.shape[0])

# %% [markdown]
# # To check the percentage of dataloss:

# %%
loss_percentage=(768-716)/768*100
print(loss_percentage,'%')
# Out:
# 6.770833333333333 %

# %% [markdown]
# checking whether how much outliers are still there. If the outliers there help in the testing the model or not

# %% [markdown]
# # Model Without Outlier is df and model with desired outliers is df_new1:

# %% [markdown]
# Diving data in features and vectors:

# %%
df_new
# Out:
#      Pregnancies  Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age  \
# 0              6      148        0  33.6                     0.627   50
# 1              1       85        0  26.6                     0.351   31
# 2              8      183        0  23.3                     0.672   32
# 3              1       89       94  28.1                     0.167   21
# 5              5      116        0  25.6                     0.201   30
# ..           ...      ...      ...   ...                       ...  ...
# 763           10      101      180  32.9                     0.171   63
# 764            2      122        0  36.8                     0.340   27
# 765            5      121      112  26.2                     0.245   30
# 766            1      126        0  30.1                     0.349   47
# 767            1       93        0  30.4                     0.315   23
#
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 5          0
# ..       ...
# 763        0
# 764        0
# 765        0
# 766        1
# 767        0
#
# [716 rows x 7 columns]

# %%
#independent column

x=df_new.iloc[:,:-1]
x
# Out:
#      Pregnancies  Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age
# 0              6      148        0  33.6                     0.627   50
# 1              1       85        0  26.6                     0.351   31
# 2              8      183        0  23.3                     0.672   32
# 3              1       89       94  28.1                     0.167   21
# 5              5      116        0  25.6                     0.201   30
# ..           ...      ...      ...   ...                       ...  ...
# 763           10      101      180  32.9                     0.171   63
# 764            2      122        0  36.8                     0.340   27
# 765            5      121      112  26.2                     0.245   30
# 766            1      126        0  30.1                     0.349   47
# 767            1       93        0  30.4                     0.315   23
#
# [716 rows x 6 columns]

# %%
y=df_new.iloc[:,-1]
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 5      0
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 716, dtype: int64

# %% [markdown]
# # Transforming data to remove Skewness

# %%
from sklearn.preprocessing import power_transform

# %%
# box-cox method for positive values and yeo-johns for other
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 0.81766344,  0.95218058, -1.00223104,  0.28114356,  0.86495337,
#          1.39031405],
#        [-0.84957557, -1.28238174, -1.00223104, -0.83047682, -0.16002044,
#          0.12808007],
#        [ 1.20277392,  1.82893792, -1.00223104, -1.43279399,  0.98450779,
#          0.23328673],
#        ...,
#        [ 0.59040907,  0.13114807,  0.96157194, -0.9003888 , -0.75346236,
#          0.0156547 ],
#        [-0.84957557,  0.29534181, -1.00223104, -0.25021575, -0.1698999 ,
#          1.26101626],
#        [-0.84957557, -0.92550642, -1.00223104, -0.2028927 , -0.34504064,
#         -1.05311184]])

# %%
#Scaling the data to normalize the date and consume less memory

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.81766344,  0.95218058, -1.00223104,  0.28114356,  0.86495337,
#          1.39031405],
#        [-0.84957557, -1.28238174, -1.00223104, -0.83047682, -0.16002044,
#          0.12808007],
#        [ 1.20277392,  1.82893792, -1.00223104, -1.43279399,  0.98450779,
#          0.23328673],
#        ...,
#        [ 0.59040907,  0.13114807,  0.96157194, -0.9003888 , -0.75346236,
#          0.0156547 ],
#        [-0.84957557,  0.29534181, -1.00223104, -0.25021575, -0.1698999 ,
#          1.26101626],
#        [-0.84957557, -0.92550642, -1.00223104, -0.2028927 , -0.34504064,
#         -1.05311184]])

# %% [markdown]
# # Since the outcome has only two variables we will use binary classification model

# %% [markdown]
# Now are going to start modelling the data.Training.machine learning model

# %%
    from sklearn.model_selection import train_test_split
    from sklearn.linear_model import LogisticRegression
    lr=LogisticRegression()
    from sklearn.metrics import accuracy_score

# %% [markdown]
# # Splitting the DataFrame

# %%
#20% for test and remaining for train

for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print("At random_state",i," The model performs very well")
        print("At random_state:-",i)
        print("Training accuracy_score is:-", round(accuracy_score(y_train,pred_train)*100,1))
        print("Testing accuracy_score is:-", round(accuracy_score(y_test,pred_test)*100,1),'\n\n')
# Out:
# At random_state 51  The model performs very well
# At random_state:- 51
# Training accuracy_score is:- 77.8
# Testing accuracy_score is:- 77.8
#
#
# At random_state 86  The model performs very well
# At random_state:- 86
# Training accuracy_score is:- 77.8
# Testing accuracy_score is:- 77.8
#
#
# At random_state 90  The model performs very well
# At random_state:- 90
# Training accuracy_score is:- 78.5
# Testing accuracy_score is:- 78.5
#
#
# At random_state 93  The model performs very well
# At random_state:- 93
# Training accuracy_score is:- 77.8
# Testing accuracy_score is:- 77.8
#
#
# At random_state 127  The model performs very well
# At random_state:- 127
# Training accuracy_score is:- 78.5
# Testing accuracy_score is:- 78.5
#
#
# At random_state 135  The model performs very well
# At random_state:- 135
# Training accuracy_score is:- 77.8
# Testing accuracy_score is:- 77.8
#
#
# At random_state 185  The model performs very well
# At random_state:- 185
# Training accuracy_score is:- 78.5
# Testing accuracy_score is:- 78.5
#
#
# At random_state 205  The model performs very well
# At random_state:- 205
# Training accuracy_score is:- 77.1
# Testing accuracy_score is:- 77.1
#
#
# At random_state 335  The model performs very well
# At random_state:- 335
# Training accuracy_score is:- 77.8
# Testing accuracy_score is:- 77.8
#
#
# At random_state 341  The model performs very well
# At random_state:- 341
# Training accuracy_score is:- 77.8
# Testing accuracy_score is:- 77.8
#
#
# At random_state 548  The model performs very well
# At random_state:- 548
# Training accuracy_score is:- 77.8
# Testing accuracy_score is:- 77.8
#
#
# At random_state 561  The model performs very well
# At random_state:- 561
# Training accuracy_score is:- 77.8
# Testing accuracy_score is:- 77.8
#
#
# At random_state 635  The model performs very well
# At random_state:- 635
# Training accuracy_score is:- 77.8
# Testing accuracy_score is:- 77.8
#
#
# At random_state 692  The model performs very well
# At random_state:- 692
# Training accuracy_score is:- 77.8
# Testing accuracy_score is:- 77.8
#
#
# At random_state 771  The model performs very well
# At random_state:- 771
# Training accuracy_score is:- 77.8
# Testing accuracy_score is:- 77.8
#
#
# At random_state 864  The model performs very well
# At random_state:- 864
# Training accuracy_score is:- 77.8
# Testing accuracy_score is:- 77.8
#
#
# At random_state 985  The model performs very well
# At random_state:- 985
# Training accuracy_score is:- 78.5
# Testing accuracy_score is:- 78.5
#
#
# At random_state 986  The model performs very well
# At random_state:- 986
# Training accuracy_score is:- 77.8
# Testing accuracy_score is:- 77.8

# %%
#selecting random state from the above result with accurate accuracy

# %%
 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=986)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.68      0.68       103
#            1       0.21      0.22      0.22        41
#
#     accuracy                           0.55       144
#    macro avg       0.45      0.45      0.45       144
# weighted avg       0.55      0.55      0.55       144

# %% [markdown]
# # Cross Validation Score for Logistic Regression

# %% [markdown]
# # as we dnt have accurate accuracy from the above result we do crosss validation

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss= accuracy_score(y_test,pred_lr)

# %%
for j in range(2,10):
    lsscore= cross_val_score(lr,x,y,cv=j)
    lsc=lsscore.mean()
    
    print("At cv:-", j)
    print("Cross Validation Score is:-", lsc*100)
    print("accuracy_score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross Validation Score is:- 77.6536312849162
# accuracy_score is:- 77.77777777777779
#
#
# At cv:- 3
# Cross Validation Score is:- 77.3777293344116
# accuracy_score is:- 77.77777777777779
#
#
# At cv:- 4
# Cross Validation Score is:- 77.09497206703911
# accuracy_score is:- 77.77777777777779
#
#
# At cv:- 5
# Cross Validation Score is:- 77.09693084693085
# accuracy_score is:- 77.77777777777779
#
#
# At cv:- 6
# Cross Validation Score is:- 77.37745098039215
# accuracy_score is:- 77.77777777777779
#
#
# At cv:- 7
# Cross Validation Score is:- 77.09880068532267
# accuracy_score is:- 77.77777777777779
#
#
# At cv:- 8
# Cross Validation Score is:- 77.2456304619226
# accuracy_score is:- 77.77777777777779
#
#
# At cv:- 9
# Cross Validation Score is:- 77.52461322081574
# accuracy_score is:- 77.77777777777779

# %% [markdown]
# Since cross validation score and accuravcy score are almost the same we are heading with a good approach

# %%
lsscore_selected=cross_val_score(lr,x,y,cv=6).mean()
print("The cv score is:-", lsscore_selected,"\nThe accuracy_score is:", lss)
# Out:
# The cv score is:- 0.7737745098039216
# The accuracy_score is: 0.7777777777777778

# %% [raw]
# #We should use the below classifiers as well to get the correct accuracy:
#
# DecisionTreeClassifier
# SVC
# KNearestClassifier
# RandonForestClassifier
# SGDClassifier

# %% [markdown]
# # The Model With the Outliers

# %% [markdown]
# # AUC ROC Curve:

# %%
from sklearn.metrics import roc_curve, auc
fpr,tpr, thresholds= roc_curve(pred_test,y_test)
roc_auc= auc(fpr,tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=10, label='ROC curve (area= %0.2f)' %roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=10, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operation Characteristic')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Accuracy should be always near 1, auc is as close as 1 we get the better model

# %% [markdown]
# # Since the model without outliers performing well! We will select that dataframe

# %% [markdown]
# # Model Saving:

# %%
import pickle
filename= 'inhouse_diabetes.pkl'
pickle.dump(lr, open(filename, 'wb'))

# %% [markdown]
# # conclusion

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(lr.predict(x_test))
df_com=pd.DataFrame({"original":a, "predicted":predicted}, index=range(len(a)))
df_com
# Out:
#      original  predicted
# 0           1          1
# 1           0          0
# 2           0          1
# 3           0          0
# 4           0          0
# ..        ...        ...
# 139         1          0
# 140         0          0
# 141         1          0
# 142         0          0
# 143         1          1
#
# [144 rows x 2 columns]
